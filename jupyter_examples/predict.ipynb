# %% [markdown]
# # Stability of Planetary Orbital Configurations Klassifier

# %%
from spock import spockClassifier

# %% [markdown]
# # Initialize our model. By default it currently loads our XGBoost summary features model

# %%
model = spockClassifier()
# Out:
# /Users/rein/git/rebound/venv/lib/python3.7/site-packages/sklearn/base.py:306: UserWarning: Trying to unpickle estimator LabelEncoder from version 0.21.2 when using version 0.21.3. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)

# %% [markdown]
# # Make a planetary configuration

# %%
import rebound
# %matplotlib inline

sim = rebound.Simulation()
sim.add(m=1.)
sim.add(m=1.e-5, P=1., e=0.03, l=0.3)
sim.add(m=1.e-5, P=1.2, e=0.03, l=2.8)
sim.add(m=1.e-5, P=1.5, e=0.03, l=-0.5)
sim.move_to_com()
fig, ax = rebound.OrbitPlot(sim)

# %% [markdown]
# # Get probability of stability

# %%
model.predict(sim)
# Out:
# /Users/rein/git/rebound/venv/lib/python3.7/site-packages/celmech/andoyer.py:98: UserWarning: k=1 resonance has no separatrix for Phiprime < 1
#   warnings.warn("k=1 resonance has no separatrix for Phiprime < 1")
# 0.0016180613
