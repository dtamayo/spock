# %% [markdown]
# # Training the SPOCK model when Integrating to one secular time scale
# in accordance with Yang & Tamayo

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn import metrics
import xgboost as xgb
from xgboost.sklearn import XGBClassifier
from hyperopt import hp, fmin, tpe, STATUS_OK, Trials
import hyperopt
import sys
sys.path.append('../spock/')
try:
    plt.style.use('paper')
except:
    pass
# %matplotlib inline

# %% [markdown]
# Start by loading the training data generated with genNewTrainData.ipynb

# %%
#load datapath for clean training data
datapath = '../../cleanData/csvs/resonant/'

dataset = pd.read_csv(datapath+'Int1Tsec.csv')
#cleanTmaxData.csv for int to Tmax
#TmaxOr1e4.csv for into to 1e4 or Tmax, whichever is greater
#remove junk columns
dataset = dataset.drop(columns=['Unnamed: 0','Unnamed: 0.1'])

# %%
dataset['InitialStable'].value_counts()
# Out:
# InitialStable
# 1.0    95968
# 0.0     6529
# Name: count, dtype: int64

# %% [markdown]
# We can then split the data into training and testing sets, note, we will remove systems that go unstable in 1e4 orbits from the testing set

# %%
def train_test(dataset,features):
    '''divides the dataset into 80% training and 20% testing and returns training/testing sets'''
    Nrows = int(0.8*dataset.shape[0])
    train = dataset.iloc[:Nrows, :]
    test = dataset.iloc[Nrows:, :]
    #remove testing systems that go unstable in 1e4 orbits

    test = test.drop(test[test['InitialStable']==False].index)
    #test = test.drop(test[test['logTmax']>3.75].index)
    return train[features], train['Stable'], test[features], test['Stable']

# %%
dataset['logTmax']=np.log10(dataset['Tmax'])

# %%
near = ['EMcrossnear', 'EMfracstdnear', 'EPstdnear', 'MMRstrengthnear']
far = ['EMcrossfar', 'EMfracstdfar', 'EPstdfar', 'MMRstrengthfar']
megno = ['MEGNO', 'MEGNOstd']

features = near + far + megno + ['Tmax']


trainX, trainY, testX, testY = train_test(dataset, features)

dtrain = xgb.DMatrix(trainX, trainY)
dtest = xgb.DMatrix(testX, testY)

# %% [markdown]
# # Tuning hyperparameter
# We can determine the idea values for the different hyperparameters.
#
# We will start by creating and testing a collection of models that have randomly selected hyperparameters

# %% [markdown]
# scale_pos_weight is a hyperparameter used to account for skewed training data, it does this by weighting false positives and negatives differently. A typical value can be obtained by dividing your negative outcomes in your training data by your positive outcomes.

# %%
trainingBalance = trainY.value_counts()[False]/trainY.value_counts()[True]

# %% [markdown]
# We can then establish the different parameter space that we will be testing different hyperparameter values within.

# %%
space ={'max_depth': hp.qloguniform('x_max_depth', np.log(5), np.log(40), 1),
        'min_child_weight': hp.loguniform('x_min_child', 0, np.log(30)),
        'subsample': hp.uniform ('x_subsample', 0.8, 1),
}

def objective(params):
    clf = XGBClassifier(n_estimators = 150,
                            max_depth = int(params['max_depth']), 
                            min_child_weight = params['min_child_weight'],
                            subsample = params['subsample'],
                            learning_rate = 0.15, seed = 0,
                            scale_pos_weight = trainingBalance)
    
    score = xgb.cv(clf.get_xgb_params(), dtrain, nfold = 5, metrics = "auc", early_stopping_rounds=10)
    avg_score =  np.mean(score["test-auc-mean"])
    error = np.mean(score["test-auc-std"])
    
    print("SCORE:", avg_score, "ERROR", error)#, "HOLDOUT SCORE", test_score)
    return{'loss':1-avg_score, 'status': STATUS_OK, "cv_score":avg_score , "cv_error":error}

# %% [markdown]
# We can then create and evaluate the different trials

# %%
# %%time
trials = Trials()
import time
start = time.time()
best = fmin(fn=objective, space = space, algo = tpe.suggest, max_evals = 100, trials = trials, rstate=np.random.default_rng(seed=0))
end = time.time()
print("Optimization Time: %f seconds", (end  -start))
# Out:
#   0%|          | 0/100 [00:00<?, ?trial/s, best loss=?]
# SCORE:
# 0.9334999425968551
# ERROR
# 0.002368817192979471
# SCORE:
# 0.9336744142487067
# ERROR
# 0.002400035403117155
# SCORE:
# 0.9381358689572478
# ERROR
# 0.002656659052561743
# SCORE:
# 0.9328028029277811
# ERROR
# 0.002901349106451076
# SCORE:
# 0.9385757164682165
# ERROR
# 0.0027055818824974665
# SCORE:
# 0.9371741237537418
# ERROR
# 0.0026433905021950115
# SCORE:
# 0.9295320964036611
# ERROR
# 0.0030107077353830588
# SCORE:
# 0.932540840351294
# ERROR
# 0.00229895816549332
# SCORE:
# 0.9324391501525915
# ERROR
# 0.0025092652297712082
# SCORE:
# 0.9367164381156681
# ERROR
# 0.002694547543822645
# SCORE:
# 0.9370279163429391
# ERROR
# 0.00221217212495155
# SCORE:
# 0.9373387950523844
# ERROR
# 0.0029039945563808203
# SCORE:
# 0.9387350314359075
# ERROR
# 0.0026537492168624654
# SCORE:
# 0.9388974466828307
# ERROR
# 0.0025372121212353534
# SCORE:
# 0.9252061280411528
# ERROR
# 0.0027071961567964277
# SCORE:
# 0.9380164580191334
# ERROR
# 0.003020525964577907
# SCORE:
# 0.9364518804783574
# ERROR
# 0.0027840817618059164
# SCORE:
# 0.9329552566416572
# ERROR
# 0.002829689985893824
# SCORE:
# 0.9388024004146688
# ERROR
# 0.0024999440162568835
# SCORE:
# 0.9367052310998876
# ERROR
# 0.0029299742204477747
# SCORE:
# 0.9391344786997788
# ERROR
# 0.002634610793409777
# SCORE:
# 0.9386505977838338
# ERROR
# 0.002349622256396275
# SCORE:
# 0.9391272314627186
# ERROR
# 0.002752557288508386
# SCORE:
# 0.9382973419182653
# ERROR
# 0.0026922698486898707
# SCORE:
# 0.9388424532337692
# ERROR
# 0.0029342567051683067
# SCORE:
# 0.9381249719414541
# ERROR
# 0.0027166869657621853
# SCORE:
# 0.9373513660886127
# ERROR
# 0.002749930382222322
# SCORE:
# 0.9377007960734488
# ERROR
# 0.0026116284183920167
# SCORE:
# 0.9389990255431124
# ERROR
# 0.002730771131679413
# SCORE:
# 0.9389739932588732
# ERROR
# 0.0028541755509526633
# SCORE:
# 0.9386209797907327
# ERROR
# 0.002472513357990537
# SCORE:
# 0.9371398446934809
# ERROR
# 0.0024034219303210006
# SCORE:
# 0.9341481301170299
# ERROR
# 0.0030829524041727776
# SCORE:
# 0.9378698314054967
# ERROR
# 0.00232973493541471
# SCORE:
# 0.9331352581620378
# ERROR
# 0.002746740622900393
# SCORE:
# 0.9383656439886725
# ERROR
# 0.0030150213761241267
# SCORE:
# 0.9387376249529351
# ERROR
# 0.0025818651120705647
# SCORE:
# 0.9368658615081653
# ERROR
# 0.003027617479974347
# SCORE:
# 0.9353939259142908
# ERROR
# 0.0024277070053441586
# SCORE:
# 0.9375409410031168
# ERROR
# 0.0027160164912884634
# SCORE:
# 0.9393644231621158
# ERROR
# 0.0027500340084017955
# SCORE:
# 0.9332207195348353
# ERROR
# 0.002615523123782497
# SCORE:
# 0.9387100432745112
# ERROR
# 0.0032022037003968462
# SCORE:
# 0.9296350028266629
# ERROR
# 0.002767696691225861
# SCORE:
# 0.938379228320461
# ERROR
# 0.002958481156032992
# SCORE:
# 0.9366305229350578
# ERROR
# 0.002822570408505316
# SCORE:
# 0.9347826243346724
# ERROR
# 0.002191784715381311
# SCORE:
# 0.9390192477409339
# ERROR
# 0.002739392200367697
# SCORE:
# 0.9251806364966562
# ERROR
# 0.0025881657356439827
# SCORE:
# 0.9391041371869451
# ERROR
# 0.002863235338983587
# SCORE:
# 0.9385557068915169
# ERROR
# 0.0031914170450817935
# SCORE:
# 0.9295700518378123
# ERROR
# 0.00240137539461795
# SCORE:
# 0.932379620790666
# ERROR
# 0.0025383236279142084
# SCORE:
# 0.9346943991245389
# ERROR
# 0.0028382684130830393
# SCORE:
# 0.9362879798363005
# ERROR
# 0.002693077115972402
# SCORE:
# 0.9335546319154862
# ERROR
# 0.0024987485627029162
# SCORE:
# 0.9357735078983834
# ERROR
# 0.002729591136771515
# SCORE:
# 0.9353980718530772
# ERROR
# 0.002809873554363641
# SCORE:
# 0.9384858600100381
# ERROR
# 0.0027788904744439095
# SCORE:
# 0.9332036223725322
# ERROR
# 0.0022305124189069
# SCORE:
# 0.9389126843372623
# ERROR
# 0.0029272089361168743
# SCORE:
# 0.9387465799366932
# ERROR
# 0.00288894151601361
# SCORE:
# 0.9389643490992963
# ERROR
# 0.002630797430488099
# SCORE:
# 0.9388111235501893
# ERROR
# 0.00285348335767179
# SCORE:
# 0.9377771826045649
# ERROR
# 0.002898496396295826
# SCORE:
# 0.9384236514497537
# ERROR
# 0.002405158358105296
# SCORE:
# 0.9388806370975618
# ERROR
# 0.0027635602122251766
# SCORE:
# 0.9381774991673988
# ERROR
# 0.0027689222105947986
# SCORE:
# 0.9371059062803682
# ERROR
# 0.0027305370231535493
# SCORE:
# 0.9387776183862868
# ERROR
# 0.0025845351613157804
# SCORE:
# 0.9379888266660326
# ERROR
# 0.0028315566953513857
# SCORE:
# 0.9380535664653868
# ERROR
# 0.0028769931234470135
# SCORE:
# 0.9372599321322784
# ERROR
# 0.002331784071237936
# SCORE:
# 0.9390581837583489
# ERROR
# 0.002692577031493397
# SCORE:
# 0.937493155621406
# ERROR
# 0.0028841415228896316
# SCORE:
# 0.9390132574136023
# ERROR
# 0.002715392576748846
# SCORE:
# 0.9384917290866905
# ERROR
# 0.002646400285533607
# SCORE:
# 0.9351443172462034
# ERROR
# 0.0024705646524763652
# SCORE:
# 0.9390600309607058
# ERROR
# 0.0031324913933020782
# SCORE:
# 0.9391489279267328
# ERROR
# 0.002801623751481697
# SCORE:
# 0.9389266069611146
# ERROR
# 0.002826104391520932
# SCORE:
# 0.9389372699451497
# ERROR
# 0.0028507006348037376
# SCORE:
# 0.9391184146981729
# ERROR
# 0.002958390578042845
# SCORE:
# 0.9367549890645955
# ERROR
# 0.0028732612088815876
# SCORE:
# 0.9388093225100782
# ERROR
# 0.002628912732354095
# SCORE:
# 0.9379874318500889
# ERROR
# 0.0026181201276789688
# SCORE:
# 0.9375767825398785
# ERROR
# 0.002768594617687399
# SCORE:
# 0.9347166294861337
# ERROR
# 0.002425908524215782
# SCORE:
# 0.9388376074147242
# ERROR
# 0.002652469911864553
# SCORE:
# 0.9385966489083397
# ERROR
# 0.0030251628043271015
# SCORE:
# 0.9389351819637867
# ERROR
# 0.002655870199955523
# SCORE:
# 0.9385306570667614
# ERROR
# 0.002738110758575112
# SCORE:
# 0.9392153953396134
# ERROR
# 0.002885828506812769
# SCORE:
# 0.9391404427695041
# ERROR
# 0.0030163185902400136
# SCORE:
# 0.9322560483714295
# ERROR
# 0.0027092725268167256
# SCORE:
# 0.9341591419103683
# ERROR
# 0.002430869255412275
# SCORE:
# 0.9329589076585968
# ERROR
# 0.0027767233519977166
# SCORE:
# 0.9390226668608508
# ERROR
# 0.0028976885056262057
# SCORE:
# 0.9388975119096095
# ERROR
# 0.0030826248417259237
# SCORE:
# 0.9391450846340431
# ERROR
# 0.0029628832740108135
# 100%|██████████| 100/100 [05:23<00:00,  3.24s/trial, best loss: 0.06063557683788423]
# Optimization Time: %f seconds 323.79008316993713
# CPU times: user 5h 35min 3s, sys: 9min 52s, total: 5h 44min 56s
# Wall time: 5min 23s

# %% [markdown]
# We can not determine what values for hyperparameters will be ideal. We can do this by plotting how AUC changes as we alter each hyperparameter.

# %% [markdown]
# Here we will find that an optimal max_depth would be 15, which gives the best performance without over fitting.

# %%
depths = trials.vals['x_max_depth']
min_childs = trials.vals['x_min_child']
subsample = trials.vals['x_subsample']
aucs = np.array([1-x['loss'] for x in trials.results])
fig, ax = plt.subplots()
ax.plot(depths, aucs, '.')
ax.axvline(15, linestyle='--')
ax.set_xlabel('max_depth')
ax.set_ylabel('CV AUC')
# Out:
# Text(0, 0.5, 'CV AUC')

# %% [markdown]
# Here we will find that an optimal min_childs would be 10, which gives the best performance without over fitting.

# %%
fig, ax = plt.subplots()
ax.plot(min_childs, aucs, '.')
ax.axvline(15, linestyle='--')
ax.set_xlabel('min_child_weight')
ax.set_ylabel('CV AUC')
# Out:
# Text(0, 0.5, 'CV AUC')

# %% [markdown]
# Here we will find that an optimal subsample value would be 0.95 due to a malignly higher concentration of high preforming models. Most values seem to give good enough results.

# %%
fig, ax = plt.subplots()
ax.plot(subsample, aucs, '.')
ax.axvline(.95, linestyle='--')
ax.set_xlabel('subsample')
ax.set_ylabel('CV AUC')
# Out:
# Text(0, 0.5, 'CV AUC')

# %% [markdown]
# We can now determine, with these new values, what the optimal number of n_estimators is.

# %%
model = XGBClassifier(learning_rate = 0.06, 
                         max_depth = 15, 
                         subsample = 0.95,
                         min_child_weight = 15,
                         scale_pos_weight = trainingBalance)

score = xgb.cv(model.get_xgb_params(), dtrain, nfold = 5, metrics = "auc", verbose_eval=True, num_boost_round=400)
# Out:
# [0]	train-auc:0.95148+0.00059	test-auc:0.92479+0.00270
# [1]	train-auc:0.95939+0.00026	test-auc:0.93289+0.00313
# [2]	train-auc:0.96247+0.00044	test-auc:0.93582+0.00290
# [3]	train-auc:0.96417+0.00036	test-auc:0.93764+0.00297
# [4]	train-auc:0.96546+0.00027	test-auc:0.93878+0.00322
# [5]	train-auc:0.96651+0.00035	test-auc:0.93959+0.00309
# [6]	train-auc:0.96744+0.00035	test-auc:0.94049+0.00296
# [7]	train-auc:0.96829+0.00033	test-auc:0.94117+0.00280
# [8]	train-auc:0.96899+0.00038	test-auc:0.94160+0.00272
# [9]	train-auc:0.96962+0.00032	test-auc:0.94200+0.00278
# [10]	train-auc:0.97031+0.00034	test-auc:0.94240+0.00266
# [11]	train-auc:0.97090+0.00035	test-auc:0.94271+0.00260
# [12]	train-auc:0.97151+0.00030	test-auc:0.94309+0.00262
# [13]	train-auc:0.97208+0.00033	test-auc:0.94344+0.00262
# [14]	train-auc:0.97264+0.00036	test-auc:0.94381+0.00255
# [15]	train-auc:0.97311+0.00038	test-auc:0.94411+0.00251
# [16]	train-auc:0.97363+0.00034	test-auc:0.94446+0.00244
# [17]	train-auc:0.97407+0.00033	test-auc:0.94471+0.00244
# [18]	train-auc:0.97453+0.00032	test-auc:0.94493+0.00250
# [19]	train-auc:0.97497+0.00030	test-auc:0.94516+0.00250
# [20]	train-auc:0.97539+0.00030	test-auc:0.94542+0.00255
# [21]	train-auc:0.97583+0.00030	test-auc:0.94566+0.00254
# [22]	train-auc:0.97622+0.00028	test-auc:0.94586+0.00254
# [23]	train-auc:0.97662+0.00027	test-auc:0.94599+0.00255
# [24]	train-auc:0.97701+0.00026	test-auc:0.94617+0.00257
# [25]	train-auc:0.97738+0.00023	test-auc:0.94637+0.00258
# [26]	train-auc:0.97773+0.00022	test-auc:0.94656+0.00260
# [27]	train-auc:0.97807+0.00020	test-auc:0.94670+0.00258
# [28]	train-auc:0.97841+0.00019	test-auc:0.94686+0.00259
# [29]	train-auc:0.97873+0.00020	test-auc:0.94700+0.00258
# [30]	train-auc:0.97903+0.00017	test-auc:0.94716+0.00258
# [31]	train-auc:0.97932+0.00017	test-auc:0.94732+0.00258
# [32]	train-auc:0.97961+0.00016	test-auc:0.94744+0.00257
# [33]	train-auc:0.97992+0.00017	test-auc:0.94760+0.00256
# [34]	train-auc:0.98020+0.00018	test-auc:0.94772+0.00257
# [35]	train-auc:0.98050+0.00017	test-auc:0.94788+0.00254
# [36]	train-auc:0.98079+0.00016	test-auc:0.94802+0.00253
# [37]	train-auc:0.98108+0.00014	test-auc:0.94814+0.00254
# [38]	train-auc:0.98136+0.00014	test-auc:0.94829+0.00251
# [39]	train-auc:0.98162+0.00013	test-auc:0.94839+0.00252
# [40]	train-auc:0.98189+0.00016	test-auc:0.94849+0.00251
# [41]	train-auc:0.98214+0.00016	test-auc:0.94860+0.00250
# [42]	train-auc:0.98240+0.00015	test-auc:0.94868+0.00249
# [43]	train-auc:0.98266+0.00014	test-auc:0.94875+0.00247
# [44]	train-auc:0.98292+0.00016	test-auc:0.94892+0.00245
# [45]	train-auc:0.98316+0.00013	test-auc:0.94898+0.00243
# [46]	train-auc:0.98338+0.00012	test-auc:0.94907+0.00242
# [47]	train-auc:0.98360+0.00011	test-auc:0.94916+0.00245
# [48]	train-auc:0.98382+0.00014	test-auc:0.94927+0.00242
# [49]	train-auc:0.98405+0.00015	test-auc:0.94935+0.00238
# [50]	train-auc:0.98427+0.00014	test-auc:0.94946+0.00238
# [51]	train-auc:0.98448+0.00014	test-auc:0.94954+0.00237
# [52]	train-auc:0.98470+0.00015	test-auc:0.94961+0.00240
# [53]	train-auc:0.98490+0.00015	test-auc:0.94969+0.00243
# [54]	train-auc:0.98510+0.00012	test-auc:0.94977+0.00243
# [55]	train-auc:0.98527+0.00012	test-auc:0.94988+0.00242
# [56]	train-auc:0.98548+0.00012	test-auc:0.94995+0.00243
# [57]	train-auc:0.98566+0.00011	test-auc:0.95004+0.00242
# [58]	train-auc:0.98583+0.00009	test-auc:0.95012+0.00243
# [59]	train-auc:0.98602+0.00009	test-auc:0.95018+0.00239
# [60]	train-auc:0.98620+0.00009	test-auc:0.95027+0.00239
# [61]	train-auc:0.98640+0.00009	test-auc:0.95035+0.00238
# [62]	train-auc:0.98655+0.00009	test-auc:0.95041+0.00240
# [63]	train-auc:0.98668+0.00009	test-auc:0.95046+0.00241
# [64]	train-auc:0.98684+0.00011	test-auc:0.95051+0.00240
# [65]	train-auc:0.98700+0.00009	test-auc:0.95056+0.00241
# [66]	train-auc:0.98717+0.00010	test-auc:0.95060+0.00242
# [67]	train-auc:0.98732+0.00010	test-auc:0.95065+0.00244
# [68]	train-auc:0.98745+0.00010	test-auc:0.95067+0.00241
# [69]	train-auc:0.98760+0.00011	test-auc:0.95072+0.00240
# [70]	train-auc:0.98772+0.00012	test-auc:0.95077+0.00239
# [71]	train-auc:0.98789+0.00010	test-auc:0.95081+0.00239
# [72]	train-auc:0.98800+0.00011	test-auc:0.95086+0.00240
# [73]	train-auc:0.98812+0.00011	test-auc:0.95091+0.00239
# [74]	train-auc:0.98824+0.00010	test-auc:0.95094+0.00237
# [75]	train-auc:0.98834+0.00010	test-auc:0.95097+0.00235
# [76]	train-auc:0.98846+0.00010	test-auc:0.95100+0.00234
# [77]	train-auc:0.98857+0.00011	test-auc:0.95104+0.00233
# [78]	train-auc:0.98868+0.00011	test-auc:0.95107+0.00233
# [79]	train-auc:0.98879+0.00012	test-auc:0.95110+0.00233
# [80]	train-auc:0.98890+0.00011	test-auc:0.95114+0.00232
# [81]	train-auc:0.98903+0.00014	test-auc:0.95119+0.00232
# [82]	train-auc:0.98917+0.00013	test-auc:0.95122+0.00232
# [83]	train-auc:0.98928+0.00013	test-auc:0.95126+0.00230
# [84]	train-auc:0.98936+0.00015	test-auc:0.95129+0.00231
# [85]	train-auc:0.98946+0.00014	test-auc:0.95133+0.00234
# [86]	train-auc:0.98955+0.00011	test-auc:0.95136+0.00233
# [87]	train-auc:0.98964+0.00011	test-auc:0.95138+0.00234
# [88]	train-auc:0.98975+0.00008	test-auc:0.95145+0.00234
# [89]	train-auc:0.98985+0.00007	test-auc:0.95149+0.00234
# [90]	train-auc:0.98996+0.00006	test-auc:0.95152+0.00235
# [91]	train-auc:0.99005+0.00006	test-auc:0.95154+0.00237
# [92]	train-auc:0.99016+0.00009	test-auc:0.95160+0.00236
# [93]	train-auc:0.99026+0.00008	test-auc:0.95162+0.00236
# [94]	train-auc:0.99034+0.00011	test-auc:0.95165+0.00235
# [95]	train-auc:0.99044+0.00011	test-auc:0.95166+0.00235
# [96]	train-auc:0.99051+0.00010	test-auc:0.95169+0.00235
# [97]	train-auc:0.99059+0.00006	test-auc:0.95172+0.00235
# [98]	train-auc:0.99067+0.00009	test-auc:0.95175+0.00234
# [99]	train-auc:0.99077+0.00010	test-auc:0.95178+0.00235
# [100]	train-auc:0.99084+0.00010	test-auc:0.95180+0.00233
# [101]	train-auc:0.99095+0.00010	test-auc:0.95183+0.00232
# [102]	train-auc:0.99100+0.00011	test-auc:0.95184+0.00231
# [103]	train-auc:0.99109+0.00008	test-auc:0.95187+0.00231
# [104]	train-auc:0.99116+0.00011	test-auc:0.95189+0.00231
# [105]	train-auc:0.99122+0.00012	test-auc:0.95192+0.00230
# [106]	train-auc:0.99131+0.00011	test-auc:0.95196+0.00229
# [107]	train-auc:0.99138+0.00010	test-auc:0.95199+0.00229
# [108]	train-auc:0.99146+0.00011	test-auc:0.95201+0.00230
# [109]	train-auc:0.99151+0.00009	test-auc:0.95204+0.00230
# [110]	train-auc:0.99157+0.00011	test-auc:0.95205+0.00230
# [111]	train-auc:0.99166+0.00015	test-auc:0.95207+0.00228
# [112]	train-auc:0.99172+0.00016	test-auc:0.95207+0.00228
# [113]	train-auc:0.99179+0.00019	test-auc:0.95210+0.00227
# [114]	train-auc:0.99185+0.00018	test-auc:0.95212+0.00225
# [115]	train-auc:0.99191+0.00018	test-auc:0.95214+0.00226
# [116]	train-auc:0.99196+0.00016	test-auc:0.95216+0.00227
# [117]	train-auc:0.99202+0.00018	test-auc:0.95216+0.00227
# [118]	train-auc:0.99211+0.00017	test-auc:0.95218+0.00227
# [119]	train-auc:0.99217+0.00019	test-auc:0.95220+0.00226
# [120]	train-auc:0.99221+0.00018	test-auc:0.95221+0.00225
# [121]	train-auc:0.99228+0.00018	test-auc:0.95223+0.00225
# [122]	train-auc:0.99234+0.00017	test-auc:0.95222+0.00224
# [123]	train-auc:0.99238+0.00018	test-auc:0.95224+0.00224
# [124]	train-auc:0.99243+0.00019	test-auc:0.95225+0.00223
# [125]	train-auc:0.99247+0.00020	test-auc:0.95227+0.00223
# [126]	train-auc:0.99253+0.00017	test-auc:0.95227+0.00223
# [127]	train-auc:0.99259+0.00019	test-auc:0.95228+0.00222
# [128]	train-auc:0.99265+0.00018	test-auc:0.95229+0.00222
# [129]	train-auc:0.99269+0.00021	test-auc:0.95231+0.00221
# [130]	train-auc:0.99274+0.00020	test-auc:0.95232+0.00221
# [131]	train-auc:0.99279+0.00020	test-auc:0.95232+0.00221
# [132]	train-auc:0.99284+0.00021	test-auc:0.95233+0.00221
# [133]	train-auc:0.99289+0.00020	test-auc:0.95233+0.00220
# [134]	train-auc:0.99294+0.00020	test-auc:0.95234+0.00220
# [135]	train-auc:0.99299+0.00019	test-auc:0.95234+0.00220
# [136]	train-auc:0.99303+0.00018	test-auc:0.95235+0.00222
# [137]	train-auc:0.99308+0.00019	test-auc:0.95237+0.00221
# [138]	train-auc:0.99315+0.00019	test-auc:0.95238+0.00222
# [139]	train-auc:0.99321+0.00020	test-auc:0.95240+0.00223
# [140]	train-auc:0.99327+0.00018	test-auc:0.95240+0.00222
# [141]	train-auc:0.99332+0.00018	test-auc:0.95242+0.00220
# [142]	train-auc:0.99339+0.00020	test-auc:0.95243+0.00220
# [143]	train-auc:0.99343+0.00019	test-auc:0.95243+0.00220
# [144]	train-auc:0.99347+0.00018	test-auc:0.95244+0.00220
# [145]	train-auc:0.99352+0.00020	test-auc:0.95244+0.00219
# [146]	train-auc:0.99356+0.00019	test-auc:0.95244+0.00220
# [147]	train-auc:0.99361+0.00019	test-auc:0.95246+0.00220
# [148]	train-auc:0.99364+0.00019	test-auc:0.95247+0.00220
# [149]	train-auc:0.99370+0.00019	test-auc:0.95248+0.00221
# [150]	train-auc:0.99374+0.00018	test-auc:0.95250+0.00220
# [151]	train-auc:0.99379+0.00017	test-auc:0.95251+0.00223
# [152]	train-auc:0.99382+0.00018	test-auc:0.95252+0.00222
# [153]	train-auc:0.99386+0.00019	test-auc:0.95253+0.00221
# [154]	train-auc:0.99390+0.00019	test-auc:0.95254+0.00221
# [155]	train-auc:0.99395+0.00019	test-auc:0.95254+0.00220
# [156]	train-auc:0.99398+0.00018	test-auc:0.95255+0.00220
# [157]	train-auc:0.99403+0.00016	test-auc:0.95255+0.00220
# [158]	train-auc:0.99409+0.00018	test-auc:0.95257+0.00219
# [159]	train-auc:0.99413+0.00018	test-auc:0.95258+0.00220
# [160]	train-auc:0.99417+0.00017	test-auc:0.95259+0.00219
# [161]	train-auc:0.99422+0.00016	test-auc:0.95261+0.00219
# [162]	train-auc:0.99426+0.00017	test-auc:0.95261+0.00219
# [163]	train-auc:0.99429+0.00018	test-auc:0.95261+0.00219
# [164]	train-auc:0.99432+0.00018	test-auc:0.95260+0.00218
# [165]	train-auc:0.99437+0.00017	test-auc:0.95261+0.00219
# [166]	train-auc:0.99440+0.00018	test-auc:0.95262+0.00218
# [167]	train-auc:0.99444+0.00017	test-auc:0.95263+0.00218
# [168]	train-auc:0.99446+0.00017	test-auc:0.95263+0.00218
# [169]	train-auc:0.99452+0.00016	test-auc:0.95264+0.00219
# [170]	train-auc:0.99456+0.00016	test-auc:0.95264+0.00219
# [171]	train-auc:0.99459+0.00015	test-auc:0.95264+0.00219
# [172]	train-auc:0.99463+0.00013	test-auc:0.95264+0.00219
# [173]	train-auc:0.99466+0.00012	test-auc:0.95265+0.00219
# [174]	train-auc:0.99471+0.00012	test-auc:0.95266+0.00218
# [175]	train-auc:0.99472+0.00012	test-auc:0.95266+0.00218
# [176]	train-auc:0.99476+0.00012	test-auc:0.95267+0.00218
# [177]	train-auc:0.99478+0.00012	test-auc:0.95267+0.00218
# [178]	train-auc:0.99481+0.00011	test-auc:0.95267+0.00218
# [179]	train-auc:0.99484+0.00011	test-auc:0.95267+0.00217
# [180]	train-auc:0.99486+0.00010	test-auc:0.95268+0.00218
# [181]	train-auc:0.99489+0.00009	test-auc:0.95268+0.00217
# [182]	train-auc:0.99492+0.00010	test-auc:0.95270+0.00217
# [183]	train-auc:0.99496+0.00009	test-auc:0.95270+0.00217
# [184]	train-auc:0.99500+0.00009	test-auc:0.95270+0.00218
# [185]	train-auc:0.99503+0.00010	test-auc:0.95270+0.00218
# [186]	train-auc:0.99505+0.00009	test-auc:0.95271+0.00218
# [187]	train-auc:0.99509+0.00011	test-auc:0.95271+0.00218
# [188]	train-auc:0.99512+0.00013	test-auc:0.95272+0.00218
# [189]	train-auc:0.99514+0.00012	test-auc:0.95272+0.00217
# [190]	train-auc:0.99517+0.00011	test-auc:0.95273+0.00217
# [191]	train-auc:0.99519+0.00012	test-auc:0.95273+0.00217
# [192]	train-auc:0.99523+0.00011	test-auc:0.95273+0.00217
# [193]	train-auc:0.99524+0.00011	test-auc:0.95273+0.00217
# [194]	train-auc:0.99527+0.00013	test-auc:0.95273+0.00217
# [195]	train-auc:0.99531+0.00012	test-auc:0.95274+0.00216
# [196]	train-auc:0.99536+0.00011	test-auc:0.95274+0.00217
# [197]	train-auc:0.99538+0.00011	test-auc:0.95275+0.00217
# [198]	train-auc:0.99541+0.00011	test-auc:0.95276+0.00215
# [199]	train-auc:0.99544+0.00013	test-auc:0.95276+0.00215
# [200]	train-auc:0.99547+0.00011	test-auc:0.95277+0.00215
# [201]	train-auc:0.99550+0.00011	test-auc:0.95276+0.00215
# [202]	train-auc:0.99555+0.00011	test-auc:0.95277+0.00216
# [203]	train-auc:0.99558+0.00010	test-auc:0.95278+0.00216
# [204]	train-auc:0.99561+0.00009	test-auc:0.95278+0.00215
# [205]	train-auc:0.99564+0.00008	test-auc:0.95277+0.00215
# [206]	train-auc:0.99567+0.00010	test-auc:0.95277+0.00215
# [207]	train-auc:0.99571+0.00009	test-auc:0.95277+0.00214
# [208]	train-auc:0.99574+0.00009	test-auc:0.95277+0.00214
# [209]	train-auc:0.99577+0.00009	test-auc:0.95277+0.00215
# [210]	train-auc:0.99579+0.00008	test-auc:0.95276+0.00215
# [211]	train-auc:0.99582+0.00008	test-auc:0.95276+0.00216
# [212]	train-auc:0.99584+0.00008	test-auc:0.95276+0.00216
# [213]	train-auc:0.99586+0.00008	test-auc:0.95276+0.00216
# [214]	train-auc:0.99588+0.00009	test-auc:0.95276+0.00216
# [215]	train-auc:0.99591+0.00008	test-auc:0.95276+0.00216
# [216]	train-auc:0.99594+0.00008	test-auc:0.95276+0.00216
# [217]	train-auc:0.99596+0.00007	test-auc:0.95277+0.00216
# [218]	train-auc:0.99598+0.00007	test-auc:0.95277+0.00216
# [219]	train-auc:0.99601+0.00007	test-auc:0.95276+0.00217
# [220]	train-auc:0.99604+0.00007	test-auc:0.95276+0.00216
# [221]	train-auc:0.99607+0.00008	test-auc:0.95276+0.00216
# [222]	train-auc:0.99610+0.00008	test-auc:0.95277+0.00216
# [223]	train-auc:0.99612+0.00008	test-auc:0.95278+0.00216
# [224]	train-auc:0.99613+0.00009	test-auc:0.95277+0.00217
# [225]	train-auc:0.99616+0.00009	test-auc:0.95278+0.00216
# [226]	train-auc:0.99619+0.00010	test-auc:0.95278+0.00216
# [227]	train-auc:0.99621+0.00011	test-auc:0.95277+0.00216
# [228]	train-auc:0.99624+0.00010	test-auc:0.95278+0.00216
# [229]	train-auc:0.99628+0.00010	test-auc:0.95277+0.00217
# [230]	train-auc:0.99631+0.00010	test-auc:0.95278+0.00216
# [231]	train-auc:0.99634+0.00009	test-auc:0.95278+0.00217
# [232]	train-auc:0.99636+0.00010	test-auc:0.95278+0.00216
# [233]	train-auc:0.99637+0.00010	test-auc:0.95279+0.00216
# [234]	train-auc:0.99640+0.00010	test-auc:0.95279+0.00216
# [235]	train-auc:0.99642+0.00009	test-auc:0.95279+0.00216
# [236]	train-auc:0.99644+0.00010	test-auc:0.95279+0.00216
# [237]	train-auc:0.99646+0.00009	test-auc:0.95279+0.00216
# [238]	train-auc:0.99648+0.00009	test-auc:0.95279+0.00216
# [239]	train-auc:0.99651+0.00010	test-auc:0.95279+0.00216
# [240]	train-auc:0.99653+0.00010	test-auc:0.95279+0.00216
# [241]	train-auc:0.99655+0.00009	test-auc:0.95279+0.00216
# [242]	train-auc:0.99657+0.00010	test-auc:0.95278+0.00216
# [243]	train-auc:0.99659+0.00010	test-auc:0.95279+0.00215
# [244]	train-auc:0.99661+0.00010	test-auc:0.95280+0.00215
# [245]	train-auc:0.99663+0.00009	test-auc:0.95280+0.00215
# [246]	train-auc:0.99666+0.00009	test-auc:0.95280+0.00215
# [247]	train-auc:0.99668+0.00008	test-auc:0.95281+0.00215
# [248]	train-auc:0.99670+0.00009	test-auc:0.95281+0.00215
# [249]	train-auc:0.99672+0.00010	test-auc:0.95279+0.00215
# [250]	train-auc:0.99675+0.00010	test-auc:0.95279+0.00215
# [251]	train-auc:0.99677+0.00011	test-auc:0.95279+0.00215
# [252]	train-auc:0.99678+0.00011	test-auc:0.95279+0.00216
# [253]	train-auc:0.99680+0.00011	test-auc:0.95279+0.00216
# [254]	train-auc:0.99682+0.00011	test-auc:0.95279+0.00216
# [255]	train-auc:0.99684+0.00010	test-auc:0.95278+0.00216
# [256]	train-auc:0.99686+0.00010	test-auc:0.95279+0.00216
# [257]	train-auc:0.99689+0.00010	test-auc:0.95280+0.00216
# [258]	train-auc:0.99691+0.00010	test-auc:0.95279+0.00216
# [259]	train-auc:0.99693+0.00011	test-auc:0.95279+0.00216
# [260]	train-auc:0.99695+0.00012	test-auc:0.95279+0.00216
# [261]	train-auc:0.99697+0.00012	test-auc:0.95279+0.00216
# [262]	train-auc:0.99698+0.00012	test-auc:0.95280+0.00215
# [263]	train-auc:0.99700+0.00011	test-auc:0.95280+0.00215
# [264]	train-auc:0.99702+0.00011	test-auc:0.95280+0.00215
# [265]	train-auc:0.99704+0.00011	test-auc:0.95281+0.00214
# [266]	train-auc:0.99705+0.00012	test-auc:0.95281+0.00215
# [267]	train-auc:0.99708+0.00011	test-auc:0.95281+0.00215
# [268]	train-auc:0.99710+0.00011	test-auc:0.95281+0.00215
# [269]	train-auc:0.99711+0.00012	test-auc:0.95281+0.00215
# [270]	train-auc:0.99713+0.00012	test-auc:0.95282+0.00215
# [271]	train-auc:0.99715+0.00013	test-auc:0.95282+0.00215
# [272]	train-auc:0.99717+0.00012	test-auc:0.95282+0.00215
# [273]	train-auc:0.99718+0.00011	test-auc:0.95282+0.00216
# [274]	train-auc:0.99720+0.00011	test-auc:0.95283+0.00215
# [275]	train-auc:0.99722+0.00011	test-auc:0.95283+0.00215
# [276]	train-auc:0.99724+0.00012	test-auc:0.95283+0.00214
# [277]	train-auc:0.99726+0.00011	test-auc:0.95283+0.00214
# [278]	train-auc:0.99728+0.00010	test-auc:0.95284+0.00215
# [279]	train-auc:0.99729+0.00010	test-auc:0.95283+0.00215
# [280]	train-auc:0.99731+0.00011	test-auc:0.95283+0.00214
# [281]	train-auc:0.99732+0.00010	test-auc:0.95282+0.00215
# [282]	train-auc:0.99734+0.00010	test-auc:0.95283+0.00214
# [283]	train-auc:0.99736+0.00010	test-auc:0.95283+0.00215
# [284]	train-auc:0.99738+0.00010	test-auc:0.95283+0.00215
# [285]	train-auc:0.99740+0.00009	test-auc:0.95283+0.00215
# [286]	train-auc:0.99741+0.00009	test-auc:0.95284+0.00215
# [287]	train-auc:0.99744+0.00009	test-auc:0.95284+0.00215
# [288]	train-auc:0.99745+0.00008	test-auc:0.95284+0.00214
# [289]	train-auc:0.99747+0.00009	test-auc:0.95284+0.00215
# [290]	train-auc:0.99749+0.00009	test-auc:0.95283+0.00215
# [291]	train-auc:0.99750+0.00010	test-auc:0.95283+0.00215
# [292]	train-auc:0.99752+0.00009	test-auc:0.95283+0.00215
# [293]	train-auc:0.99753+0.00009	test-auc:0.95284+0.00216
# [294]	train-auc:0.99755+0.00009	test-auc:0.95284+0.00217
# [295]	train-auc:0.99757+0.00009	test-auc:0.95284+0.00217
# [296]	train-auc:0.99758+0.00009	test-auc:0.95284+0.00217
# [297]	train-auc:0.99760+0.00009	test-auc:0.95285+0.00217
# [298]	train-auc:0.99761+0.00008	test-auc:0.95285+0.00217
# [299]	train-auc:0.99763+0.00009	test-auc:0.95285+0.00218
# [300]	train-auc:0.99764+0.00010	test-auc:0.95285+0.00218
# [301]	train-auc:0.99766+0.00009	test-auc:0.95285+0.00218
# [302]	train-auc:0.99767+0.00009	test-auc:0.95285+0.00218
# [303]	train-auc:0.99768+0.00009	test-auc:0.95285+0.00218
# [304]	train-auc:0.99769+0.00009	test-auc:0.95284+0.00218
# [305]	train-auc:0.99770+0.00010	test-auc:0.95283+0.00218
# [306]	train-auc:0.99772+0.00009	test-auc:0.95283+0.00219
# [307]	train-auc:0.99774+0.00010	test-auc:0.95283+0.00218
# [308]	train-auc:0.99776+0.00010	test-auc:0.95282+0.00218
# [309]	train-auc:0.99777+0.00010	test-auc:0.95282+0.00219
# [310]	train-auc:0.99778+0.00010	test-auc:0.95283+0.00218
# [311]	train-auc:0.99780+0.00010	test-auc:0.95283+0.00219
# [312]	train-auc:0.99781+0.00010	test-auc:0.95283+0.00219
# [313]	train-auc:0.99783+0.00009	test-auc:0.95283+0.00219
# [314]	train-auc:0.99784+0.00009	test-auc:0.95282+0.00219
# [315]	train-auc:0.99786+0.00009	test-auc:0.95282+0.00219
# [316]	train-auc:0.99787+0.00008	test-auc:0.95282+0.00219
# [317]	train-auc:0.99788+0.00009	test-auc:0.95282+0.00219
# [318]	train-auc:0.99790+0.00009	test-auc:0.95282+0.00219
# [319]	train-auc:0.99791+0.00009	test-auc:0.95282+0.00218
# [320]	train-auc:0.99792+0.00009	test-auc:0.95282+0.00218
# [321]	train-auc:0.99794+0.00009	test-auc:0.95283+0.00218
# [322]	train-auc:0.99795+0.00010	test-auc:0.95282+0.00219
# [323]	train-auc:0.99797+0.00009	test-auc:0.95282+0.00218
# [324]	train-auc:0.99797+0.00009	test-auc:0.95282+0.00217
# [325]	train-auc:0.99799+0.00009	test-auc:0.95281+0.00218
# [326]	train-auc:0.99800+0.00008	test-auc:0.95282+0.00218
# [327]	train-auc:0.99801+0.00008	test-auc:0.95282+0.00218
# [328]	train-auc:0.99803+0.00008	test-auc:0.95282+0.00218
# [329]	train-auc:0.99805+0.00008	test-auc:0.95281+0.00220
# [330]	train-auc:0.99806+0.00007	test-auc:0.95281+0.00220
# [331]	train-auc:0.99808+0.00007	test-auc:0.95282+0.00220
# [332]	train-auc:0.99809+0.00007	test-auc:0.95282+0.00220
# [333]	train-auc:0.99810+0.00008	test-auc:0.95282+0.00220
# [334]	train-auc:0.99812+0.00008	test-auc:0.95282+0.00220
# [335]	train-auc:0.99813+0.00008	test-auc:0.95282+0.00220
# [336]	train-auc:0.99815+0.00007	test-auc:0.95283+0.00219
# [337]	train-auc:0.99816+0.00008	test-auc:0.95283+0.00219
# [338]	train-auc:0.99817+0.00008	test-auc:0.95282+0.00219
# [339]	train-auc:0.99818+0.00007	test-auc:0.95282+0.00219
# [340]	train-auc:0.99819+0.00007	test-auc:0.95282+0.00219
# [341]	train-auc:0.99820+0.00007	test-auc:0.95282+0.00219
# [342]	train-auc:0.99821+0.00007	test-auc:0.95282+0.00218
# [343]	train-auc:0.99822+0.00007	test-auc:0.95281+0.00218
# [344]	train-auc:0.99824+0.00007	test-auc:0.95281+0.00218
# [345]	train-auc:0.99824+0.00007	test-auc:0.95281+0.00218
# [346]	train-auc:0.99825+0.00006	test-auc:0.95281+0.00218
# [347]	train-auc:0.99827+0.00006	test-auc:0.95281+0.00218
# [348]	train-auc:0.99828+0.00006	test-auc:0.95282+0.00218
# [349]	train-auc:0.99829+0.00006	test-auc:0.95282+0.00218
# [350]	train-auc:0.99830+0.00006	test-auc:0.95282+0.00218
# [351]	train-auc:0.99831+0.00006	test-auc:0.95282+0.00218
# [352]	train-auc:0.99832+0.00007	test-auc:0.95281+0.00220
# [353]	train-auc:0.99833+0.00007	test-auc:0.95281+0.00219
# [354]	train-auc:0.99835+0.00007	test-auc:0.95281+0.00220
# [355]	train-auc:0.99836+0.00007	test-auc:0.95281+0.00220
# [356]	train-auc:0.99837+0.00007	test-auc:0.95281+0.00221
# [357]	train-auc:0.99838+0.00007	test-auc:0.95281+0.00220
# [358]	train-auc:0.99838+0.00007	test-auc:0.95281+0.00220
# [359]	train-auc:0.99840+0.00007	test-auc:0.95281+0.00220
# [360]	train-auc:0.99840+0.00007	test-auc:0.95281+0.00221
# [361]	train-auc:0.99842+0.00007	test-auc:0.95280+0.00221
# [362]	train-auc:0.99843+0.00007	test-auc:0.95280+0.00221
# [363]	train-auc:0.99844+0.00007	test-auc:0.95280+0.00220
# [364]	train-auc:0.99845+0.00007	test-auc:0.95280+0.00220
# [365]	train-auc:0.99846+0.00007	test-auc:0.95280+0.00220
# [366]	train-auc:0.99848+0.00007	test-auc:0.95279+0.00220
# [367]	train-auc:0.99848+0.00007	test-auc:0.95279+0.00220
# [368]	train-auc:0.99849+0.00007	test-auc:0.95278+0.00220
# [369]	train-auc:0.99850+0.00007	test-auc:0.95279+0.00220
# [370]	train-auc:0.99851+0.00007	test-auc:0.95278+0.00219
# [371]	train-auc:0.99852+0.00008	test-auc:0.95278+0.00219
# [372]	train-auc:0.99853+0.00008	test-auc:0.95277+0.00218
# [373]	train-auc:0.99854+0.00008	test-auc:0.95277+0.00218
# [374]	train-auc:0.99854+0.00008	test-auc:0.95276+0.00218
# [375]	train-auc:0.99856+0.00008	test-auc:0.95276+0.00217
# [376]	train-auc:0.99857+0.00008	test-auc:0.95275+0.00217
# [377]	train-auc:0.99858+0.00008	test-auc:0.95275+0.00217
# [378]	train-auc:0.99859+0.00007	test-auc:0.95275+0.00217
# [379]	train-auc:0.99860+0.00007	test-auc:0.95275+0.00218
# [380]	train-auc:0.99861+0.00006	test-auc:0.95274+0.00218
# [381]	train-auc:0.99862+0.00007	test-auc:0.95273+0.00218
# [382]	train-auc:0.99863+0.00006	test-auc:0.95273+0.00218
# [383]	train-auc:0.99864+0.00007	test-auc:0.95273+0.00219
# [384]	train-auc:0.99865+0.00007	test-auc:0.95273+0.00219
# [385]	train-auc:0.99866+0.00007	test-auc:0.95273+0.00218
# [386]	train-auc:0.99868+0.00007	test-auc:0.95274+0.00219
# [387]	train-auc:0.99869+0.00007	test-auc:0.95272+0.00218
# [388]	train-auc:0.99869+0.00007	test-auc:0.95272+0.00219
# [389]	train-auc:0.99870+0.00007	test-auc:0.95272+0.00219
# [390]	train-auc:0.99871+0.00007	test-auc:0.95271+0.00219
# [391]	train-auc:0.99872+0.00007	test-auc:0.95272+0.00220
# [392]	train-auc:0.99873+0.00007	test-auc:0.95272+0.00221
# [393]	train-auc:0.99874+0.00007	test-auc:0.95273+0.00221
# [394]	train-auc:0.99875+0.00007	test-auc:0.95273+0.00221
# [395]	train-auc:0.99876+0.00006	test-auc:0.95272+0.00222
# [396]	train-auc:0.99877+0.00006	test-auc:0.95273+0.00222
# [397]	train-auc:0.99878+0.00006	test-auc:0.95273+0.00222
# [398]	train-auc:0.99878+0.00006	test-auc:0.95272+0.00222
# [399]	train-auc:0.99879+0.00006	test-auc:0.95273+0.00223

# %% [markdown]
# Here we will find that an optimal number of estimators would be about 125.

# %%
n_estimators = 200
fig, ax = plt.subplots()
ax.plot(score.index, score['train-auc-mean'], label='Train')
ax.plot(score.index, score['test-auc-mean'], label='Test')
ax.axvline(n_estimators, linestyle='--')
ax.legend()
ax.set_xlabel('n_estimators (num trees)')
ax.set_ylabel('CV AUC score')
# Out:
# Text(0, 0.5, 'CV AUC score')

# %% [markdown]
# # SPOCK

# %% [markdown]
# We can now train the final spock model

# %%
dataset['logTmax']=np.log10(dataset['Tmax'])

# %%
from sklearn import metrics
from sklearn.metrics import roc_curve, confusion_matrix, auc
def ROC_curve( model, x,y):
    preds = model.predict_proba(x)[:,1]
    fpr, tpr, ROCthresholds = roc_curve(y, preds)
    roc_auc = metrics.roc_auc_score(y, preds)
    return roc_auc, fpr, tpr, ROCthresholds

# %%
model = XGBClassifier(learning_rate = 0.06, 
                         max_depth = 15, 
                         subsample = 0.95,
                         min_child_weight = 15,
                         n_estimators = 200,
                         scale_pos_weight=trainingBalance)

# %%
model.fit(trainX,trainY)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.06, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=15, max_leaves=None,
#               min_child_weight=15, missing=nan, monotone_constraints=None,
#               n_estimators=200, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, ...)

# %%
roc_auc, fpr, tpr, ROCthresholds = ROC_curve(model, testX, testY)

fig, ax = plt.subplots()
ax.plot(fpr, tpr)
ax.plot([0, 1], [0, 1], 'k--')
ax.set_xlim([0.0, 1.0])
ax.set_ylim([0.0, 1.0])
ax.set_xlabel('False Positive Rate')
ax.set_ylabel('True Positive Rate')
ax.set_title('ROC curve (AUC = {0:.3f})'.format(roc_auc))
# Out:
# Text(0.5, 1.0, 'ROC curve (AUC = 0.952)')

# %%
#check exact number
roc_auc
# Out:
# 0.9522110698532896

# %% [markdown]
# We can check FPR when we have a TPR of .9

# %%
tprthreshindex = np.where(tpr >=0.9)[0][0]
fpr[tprthreshindex]
# Out:
# 0.14367176634214188

# %% [markdown]
# We can check feature importance

# %%
feat_imp = pd.Series(model.get_booster().get_fscore()).sort_values(ascending=False)
ax = feat_imp.plot.barh(figsize=(12,6), fontsize=24)
ax.set_xlabel('Feature Importance Score', fontsize=24)
ax.invert_yaxis()

# %% [markdown]
# Here we can see that the model trained with features generated by integrating to 5 times the secular time scale preforms only slightly better then if you only integrate to 1e4. Since integrating based on the secular time scale has a large negative impact on the computational power required, we can conclude that the cost is not worth the benifit.

# %%
dataset.hist('logTmax')
# Out:
# array([[<Axes: title={'center': 'logTmax'}>]], dtype=object)

# %% [markdown]
# # Comparing to original spock model

# %%
#load datapath for clean training data that was integrated to 1e4
datapath = '../../cleanData/csvs/resonant/'

regtime = pd.read_csv(datapath+'CleanResTrainingData.csv')
#remove junk columns
regtime = regtime.drop(columns=['Unnamed: 0','Unnamed: 0.1'])
regtime = regtime[features[:-1]+['Stable','InitialStable']]
#keep track of which systems are unstable in secular timescale
initStab = (dataset ['InitialStable'] ==1) & (regtime ['InitialStable'] ==1)

# %% [markdown]
# We will not test on systems that are initially unstable in either short intigration

# %%
regtime['InitialStable']= initStab
dataset['InitialStable']= initStab
# overwrite initial stable so we can use our automated filtration to compair

# %% [markdown]
# re split data into training and testing

# %%
Otrainx,Otrainy,Otestx,OtestY =train_test(regtime, features[:-1]) # removing Tmax as a feature for the old model
Otrainx,Otrainy,TsecX,TsecY =train_test(regtime, features[:-1]) 
#training data does not matter

# %% [markdown]
# # Evaluate Old

# %%
from spock import FeatureClassifier
spock = FeatureClassifier()
# evaluates old model trained with 1e4 integrations on data
Oldauc, Oldfpr, Oldtpr, ROCthresholds = ROC_curve(spock.model, Otestx, OtestY)


fig, ax = plt.subplots()
ax.plot(Oldfpr, Oldtpr)
ax.plot([0, 1], [0, 1], 'k--')
ax.set_xlim([0.0, 1.0])
ax.set_ylim([0.0, 1.0])
ax.set_xlabel('False Positive Rate')
ax.set_ylabel('True Positive Rate')
ax.set_title('ROC curve (AUC = {0:.3f})'.format(Oldauc))
# Out:
# Text(0.5, 1.0, 'ROC curve (AUC = 0.944)')

# %%
Oldauc
# Out:
# 0.9436352768410051

# %%
tprthreshindex = np.where(Oldtpr >=0.9)[0][0]
Oldfpr[tprthreshindex]
# Out:
# 0.163252508361204

# %% [markdown]
# # Evaluate model integrated to secular time scale

# %%
Tsecauc, Tsecfpr, Tsectpr, ROCthresholds = ROC_curve(model, testX, testY)

fig, ax = plt.subplots()
ax.plot(Tsecfpr, Tsectpr)
ax.plot([0, 1], [0, 1], 'k--')
ax.set_xlim([0.0, 1.0])
ax.set_ylim([0.0, 1.0])
ax.set_xlabel('False Positive Rate')
ax.set_ylabel('True Positive Rate')
ax.set_title('ROC curve (AUC = {0:.3f})'.format(Tsecauc))
# Out:
# Text(0.5, 1.0, 'ROC curve (AUC = 0.952)')

# %%
Tsecauc
# Out:
# 0.9522110698532896

# %%
tprthreshindex = np.where(Tsectpr >=0.9)[0][0]
Tsecfpr[tprthreshindex]
# Out:
# 0.14367176634214188

# %% [markdown]
# # Comparison
# When evaluated on the same testing data set where no system goes unstable in either short integration
#
# Integrating to secular time scale has a AUC of **0.9522** and a FPR when TPR=0.9 of **0.1437**
#
# Integrating to 1e4 orbits evaluated on systems that are stable in both after integration has a AUC of **0.9436** and a FPR when TPR=0.9 of **0.1633**
#
# **Conclusion**
#
# Integrating to one secular time scale and passing the time scale forward as a feature results in a increase of AUC by 0.86 percentage points and a decrease in FPR by 1.96 percentage points when being evaluated on the same dataset.
