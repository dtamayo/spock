# %% [markdown]
# # This version of training data will be run using the old version of rebound, pre v4, to ensure compatibility

# %%
import sys
sys.path.insert(1,'../')
import spock
import random
import numpy as np
import rebound
import pandas as pd
#from spock import simsetup
from spock import FeatureClassifier

# %% [markdown]
# Ensure rebound version is less then 4:

# %%
rebound.__version__
# Out:
# '3.4.0'

# %%
#specify the data path
#We will be using cleaned data generated from the original spock initial conditions data, filtered according to https://github.com/Ethadhani/SPOCKcleanData.git
datapath = '../../cleanData/csvs/resonant/'
initial = pd.read_csv(datapath+'clean_initial_conditions.csv')
labels = pd.read_csv(datapath+'clean_labels.csv')
#drop junk column
initial = initial.drop('Unnamed: 0', axis = 1)
#merge labels and initial conditions based on runstring
Initialdataset = initial.set_index('runstring').join(labels.set_index('runstring'))
Initialdataset = Initialdataset.drop('Unnamed: 0', axis = 1)

# %%
labels
# Out:
#         Unnamed: 0    runstring  instability_time  shadow_instability_time  \
# 0                0  0000000.bin      1.545872e+06             3.063700e+06
# 1                1  0000001.bin      9.990000e+08             9.990000e+08
# 2                2  0000002.bin      9.990000e+08             9.990000e+08
# 3                3  0000003.bin      2.287671e+06             8.392234e+06
# 4                4  0000004.bin      9.668931e+05             3.380350e+05
# ...            ...          ...               ...                      ...
# 102492      113537  9044761.bin      6.303165e+04             6.470086e+04
# 102493      113538  9045377.bin      6.990387e+05             8.267916e+05
# 102494      113540  9045380.bin      1.193822e+07             3.363291e+07
# 102495      113541  9045382.bin      2.064407e+08             4.316851e+07
# 102496      113542  9045383.bin      2.266066e+04             2.228425e+04
#
#         Stable
# 0        False
# 1         True
# 2         True
# 3        False
# 4        False
# ...        ...
# 102492   False
# 102493   False
# 102494   False
# 102495   False
# 102496   False
#
# [102497 rows x 5 columns]

# %% [markdown]
# We can establish a function that, given a list of initial conditions, will return a rebound simulation

# %%
def get_sim(row, dataset):
    '''Given a row number, and a data sheet containing initial conditions, returns a corresponding simulation
    
        Arguments:
            row: what row the simulation you would like to create is on
                format of row is in order: 
                [index, 'p0m', 'p0x', 'p0y', 'p0z', 'p0vx', 'p0vy', 'p0vz', 'p1m', 'p1x', 'p1y',
                'p1z', 'p1vx', 'p1vy', 'p1vz', 'p2m', 'p2x', 'p2y', 'p2z', 'p2vx',
                'p2vy', 'p2vz', 'p3m', 'p3x', 'p3y', 'p3z', 'p3vx', 'p3vy', 'p3vz']

            dataset: what dataset contains your initial conditions

        return: returns a rebound simulation with the specified initial conditions'''
    try:
        data = dataset.loc[row]
        sim = rebound.Simulation()
        sim.G=4*np.pi**2
        sim.add(m=data['p0m'], x=data['p0x'], y=data['p0y'], z=data['p0z'], vx=data['p0vx'], vy=data['p0vy'], vz=data['p0vz'])
        sim.add(m=data['p1m'], x=data['p1x'], y=data['p1y'], z=data['p1z'], vx=data['p1vx'], vy=data['p1vy'], vz=data['p1vz'])
        sim.add(m=data['p2m'], x=data['p2x'], y=data['p2y'], z=data['p2z'], vx=data['p2vx'], vy=data['p2vy'], vz=data['p2vz'])
        sim.add(m=data['p3m'], x=data['p3x'], y=data['p3y'], z=data['p3z'], vx=data['p3vx'], vy=data['p3vy'], vz=data['p3vz'])
        return sim
    except:
        print("Error reading initial condition {0}".format(row))
        return None

# %% [markdown]
# We can now generate the set row indices of all simulations

# %%
#generates the indexes of the systems
systemNum = range(Initialdataset.shape[0])

# %% [markdown]
# We can note the column names and import the different feature generators

# %%
col = ['EMcrossnear', 'EMfracstdnear', 'EPstdnear', 'MMRstrengthnear', 'EMcrossfar', 'EMfracstdfar', 'EPstdfar', 'MMRstrengthfar', 'MEGNO', 'MEGNOstd']

# %%
spock = FeatureClassifier()

# %%
def getList(features):
    '''Helper function which isolates the data list from the generate_features return'''
    return list(features[0][0].values())

# %%
def getFeat(num):
    '''when given a index of a row, loads initial conditions and returns the spock generated features'''
    #gets features based on index num
    sim = get_sim(num,initial)
    return spock.generate_features(sim)

# %%
sim = get_sim(102492,initial)

# %%
sim.integrate(1e5)

# %% [markdown]
# For the purpose of the comparison, we will have to comment out line 95 of featureclassifier.py (s = s.copy()) since old version of rebound and newer versions of python have trouble with the copy

# %% [markdown]
# We can then map the getFeat function to all of the row indices in order generate all features and create a dataset

# %%
import sys
from multiprocessing import Pool
sys.path.append('spockUpdate/train_models')
#import is required to get around jupyter notebook bug with multiprocessing
import genNewTrainHelper as helper
if __name__ == "__main__":
    with Pool() as pool:
        features = pool.map(getFeat,systemNum)
        pool.close()
        pool.join()
#formats the data correctly
formattedFeat = pd.DataFrame(np.array(list(map(getList,features))), columns = col)
# Out:
# ---------------------------------------------------------------------------
# RemoteTraceback                           Traceback (most recent call last)
# RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/home/ethadhani/spockUpdate/generate_training_data/../spock/ClassifierSeries.py", line 42, in get_tseries
#     sim.integrate(time, exact_finish_time=0)
#   File "/home/ethadhani/rebound/rebound/simulation.py", line 1392, in integrate
#     raise Escape("A particle escaped (r>exit_max_distance).")
# rebound.Escape: A particle escaped (r>exit_max_distance).
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/miniconda3/envs/OldSpock/lib/python3.12/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#                     ^^^^^^^^^^^^^^^^^^^
#   File "/home/miniconda3/envs/OldSpock/lib/python3.12/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#            ^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_41944/1925981017.py", line 4, in getFeat
#     return spock.generate_features(sim)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ethadhani/spockUpdate/generate_training_data/../spock/featureclassifier.py", line 54, in generate_features
#     data = self.simToData(sim)
#            ^^^^^^^^^^^^^^^^^^^
#   File "/home/ethadhani/spockUpdate/generate_training_data/../spock/featureclassifier.py", line 82, in simToData
#     return [self.run(sim[0])]
#             ^^^^^^^^^^^^^^^^
#   File "/home/ethadhani/spockUpdate/generate_training_data/../spock/featureclassifier.py", line 100, in run
#     return self.runSim(s,featureargs) #adds data to results. calls runSim helper function which returns the data list for sim
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ethadhani/spockUpdate/generate_training_data/../spock/featureclassifier.py", line 114, in runSim
#     triotseries, stable = ClassifierSeries.get_tseries(sim, args) #runs the intigration on the simulation, and returns the filled objects for each trio and short stability
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ethadhani/spockUpdate/generate_training_data/../spock/ClassifierSeries.py", line 43, in get_tseries
#     except (rebound.Collision, rebound.Escape):
#             ^^^^^^^^^^^^^^^^^
# AttributeError: module 'rebound' has no attribute 'Collision'
# """
#
# The above exception was the direct cause of the following exception:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 8
#       6 if __name__ == "__main__":
#       7     with Pool() as pool:
# ----> 8         features = pool.map(getFeat,systemNum)
#       9         pool.close()
#      10         pool.join()
#
# File /home/miniconda3/envs/OldSpock/lib/python3.12/multiprocessing/pool.py:367, in Pool.map(self, func, iterable, chunksize)
#     362 def map(self, func, iterable, chunksize=None):
#     363     '''
#     364     Apply `func` to each element in `iterable`, collecting the results
#     365     in a list that is returned.
#     366     '''
# --> 367     return self._map_async(func, iterable, mapstar, chunksize).get()
#
# File /home/miniconda3/envs/OldSpock/lib/python3.12/multiprocessing/pool.py:774, in ApplyResult.get(self, timeout)
#     772     return self._value
#     773 else:
# --> 774     raise self._value
#
# AttributeError: module 'rebound' has no attribute 'Collision'

# %% [markdown]
# We can then join the generated features with the corresponding labels

# %%
dataset = pd.DataFrame.join(formattedFeat,labels)

# %%
dataset
# Out:
#         EMcrossnear  EMfracstdnear  EPstdnear  MMRstrengthnear  EMcrossfar  \
# 0          0.060234       0.030043   0.000283         0.491222    0.504063
# 1          0.080547       0.017239   0.000138         0.432211    0.240504
# 2          0.129660       0.028785   0.000989         1.000486    1.001981
# 3          0.406112       0.038118   0.000942         0.348009    0.427768
# 4          0.059897       0.026167   0.001919         0.285146    0.257596
# ...             ...            ...        ...              ...         ...
# 102492     0.089252       0.274872   0.011063         0.050574    0.310694
# 102493     0.082222       0.049940   0.016289         0.614960    0.664222
# 102494     0.131799       0.027696   0.001457         0.660450    0.366664
# 102495     0.209454       0.090838   0.010214         1.438882    0.395073
# 102496     0.182523            NaN        NaN              NaN    0.430482
#
#         EMfracstdfar  EPstdfar  MMRstrengthfar      MEGNO   MEGNOstd  \
# 0           0.000882  0.000330             NaN   1.991877   0.003666
# 1           0.008924  0.002141        0.008266   1.994730   0.003807
# 2           0.000513  0.000936        0.010448   1.975245   0.015875
# 3           0.035020  0.003593        0.012846   2.002438   0.000682
# 4           0.052339  0.001386        0.032904   1.805866   0.080916
# ...              ...       ...             ...        ...        ...
# 102492      0.033604  0.000987        1.041204  75.482329  20.204394
# 102493      0.031330  0.003745             NaN   1.998822   0.003453
# 102494      0.067480  0.020412        0.005440   7.135916   1.918209
# 102495      0.102280  0.038515        0.041145   2.117164   0.088393
# 102496           NaN       NaN             NaN        NaN        NaN
#
#         Unnamed: 0    runstring  instability_time  shadow_instability_time  \
# 0                0  0000000.bin      1.545872e+06             3.063700e+06
# 1                1  0000001.bin      9.990000e+08             9.990000e+08
# 2                2  0000002.bin      9.990000e+08             9.990000e+08
# 3                3  0000003.bin      2.287671e+06             8.392234e+06
# 4                4  0000004.bin      9.668931e+05             3.380350e+05
# ...            ...          ...               ...                      ...
# 102492      113537  9044761.bin      6.303165e+04             6.470086e+04
# 102493      113538  9045377.bin      6.990387e+05             8.267916e+05
# 102494      113540  9045380.bin      1.193822e+07             3.363291e+07
# 102495      113541  9045382.bin      2.064407e+08             4.316851e+07
# 102496      113542  9045383.bin      2.266066e+04             2.228425e+04
#
#         Stable
# 0        False
# 1         True
# 2         True
# 3        False
# 4        False
# ...        ...
# 102492   False
# 102493   False
# 102494   False
# 102495   False
# 102496   False
#
# [102497 rows x 15 columns]

# %% [markdown]
# We can then save the new training data spreadsheet

# %%
dataset.to_csv(datapath+'OldReboundCleanResTrainingData.csv')
