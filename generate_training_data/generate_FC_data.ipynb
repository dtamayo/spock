# %% [markdown]
# # Generate SPOCK training data

# %%
import spock
import random
import numpy as np
import rebound
import pandas as pd
from spock import simsetup
from spock import FeatureClassifier

# %% [markdown]
# The initial conditions are stored as snapshots of a simulation archive, we must thus load the datapath and the labels for the corresponding systems

# %%
#specify the data path
#We will be using cleaned data generated from the original spock initial conditions data
# This data is in the form of a simulation archive
datapath = '../training_data/dataset/resonant/'
labels = pd.read_csv(datapath+'sim_labels.csv')

# %% [markdown]
# We can now generate the set of system indices based on the labels

# %%
#generates the indexes of the systems
systemNum = range(labels.shape[0])

# %%
spock = FeatureClassifier()

# %% [markdown]
# We can then establish some helper functions that will allow us to map the spock.generate_feature function to the different systems by mapping to the different snapshots

# %%
def getList(features):
    '''Helper function which isolates the data list from the generate_features return'''
    return list(features[0][0].values())+[features[1]]

# %%
def getFeat(num):
    '''when given a index of a row, loads initial conditions and returns the spock generated features'''
    #gets features based on index num
    sim = rebound.Simulation(datapath+"clean_initial_conditions.bin", snapshot=num)
    return spock.generate_features(sim)

# %%
rebound.__version__
# Out:
# '4.4.6'

# %% [markdown]
# We can now map getFeat to the different rows of the Initial df, this will create each simulation and generate the spock features.

# %%
sim = rebound.Simulation(datapath+"clean_initial_conditions.bin", snapshot=3)
spock.generate_features(sim)
# Out:
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/rebound/simulation.py:153: RuntimeWarning: Binary file was saved with a different version of REBOUND. Binary format might have changed.
#   warnings.warn(message, RuntimeWarning)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 sim = rebound.Simulation(datapath+"clean_initial_conditions.bin", snapshot=3)
# ----> 2 spock.generate_features(sim)
#
# File ~/spockUpdate/spock/featureclassifier.py:96, in FeatureClassifier.generate_features(self, sim, n_jobs, Nbodytmax)
#      85 def generate_features(self, sim, n_jobs = -1, Nbodytmax = 1e6):
#      86     '''helper function to fit spock syntax standard
#      87         Arguments:
#      88                 sim: simulation or list of simulations
#    (...)
#      94         return: features for given system or list of systems
#      95     '''
# ---> 96     data = self.simToData(sim, n_jobs, Nbodytmax)
#      97     # Nicely wraps data if only evaluating one system
#      98     if len(data) == 1:
#
# File ~/spockUpdate/spock/featureclassifier.py:121, in FeatureClassifier.simToData(self, sim, n_jobs, Nbodytmax)
#     117     sim = [sim]
#     119 if len(sim)==1:
#     120     #retuns the data for a single simulation
# --> 121     return [self.run(sim[0], Nbodytmax)]
#     122 else:
#     123     #if more then one sim is passed, uses thread pooling
#     124     #to generate data for each
#     125     if n_jobs == -1:
#
# File ~/spockUpdate/spock/featureclassifier.py:175, in FeatureClassifier.run(self, s, Nbodytmax)
#     172 featureargs = [Norbits, Nout, trios]
#     173 # adds data to results.
#     174 # calls runSim helper function which returns the data list for sim
# --> 175 return self.runSim(s, featureargs)
#
# File ~/spockUpdate/spock/featureclassifier.py:191, in FeatureClassifier.runSim(self, sim, args)
#     179 '''returns the data list of features for a given simulation
#     180
#     181     Arguments:
#    (...)
#     187             and whether sys stable in short integration
#     188 '''
#     189 # runs the intigration on the simulation,
#     190 # and returns the filled objects for each trio and short stability
# --> 191 triotseries, stable = ClassifierSeries.get_tseries(sim, args)
#     192 # calculate final vals
#     193 dataList = []
#
# File ~/spockUpdate/spock/ClassifierSeries.py:41, in get_tseries(sim, args)
#      35 # forms the list that will later consist of each trio pair,
#      36 # and the tseries for each list
#      38 for tr, trio in enumerate(trios): # in each trio there is two adjacent pairs
#      39     # fills triopairs with each pair,
#      40     # and fills triotseries with the Trio class
# ---> 41     triotseries.append(features.Trio(trio, sim))
#      42     triotseries[tr].fillVal(Nout)
#      43     # puts in the valeus that depend on initial cond
#
# TypeError: Trio.__init__() missing 1 required positional argument: 'Nout'

# %%
import sys
from multiprocessing import Pool
if __name__ == "__main__":
    with Pool() as pool:
        features = pool.map(getFeat,systemNum)
        pool.close()
        pool.join()
#formats the data correctly regardless of features
formattedFeat = pd.DataFrame(np.array(list(map(getList,features))), 
                             columns = list(features[0][0][0].keys())+['InitialStable'])
# Out:
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:353: RuntimeWarning: overflow encountered in scalar multiply
#   return 2 * poch(s,j) * alpha**j * hyp2f1(s,s+j,j+1,alpha**2)/ factorial(j)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:349: RuntimeWarning: invalid value encountered in scalar add
#   laplace_b(s+1,j-1,0,alpha)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:349: RuntimeWarning: invalid value encountered in scalar subtract
#   laplace_b(s+1,j-1,0,alpha)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:353: RuntimeWarning: invalid value encountered in scalar divide
#   return 2 * poch(s,j) * alpha**j * hyp2f1(s,s+j,j+1,alpha**2)/ factorial(j)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:353: RuntimeWarning: overflow encountered in scalar multiply
#   return 2 * poch(s,j) * alpha**j * hyp2f1(s,s+j,j+1,alpha**2)/ factorial(j)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:349: RuntimeWarning: invalid value encountered in scalar add
#   laplace_b(s+1,j-1,0,alpha)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:349: RuntimeWarning: invalid value encountered in scalar subtract
#   laplace_b(s+1,j-1,0,alpha)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:353: RuntimeWarning: invalid value encountered in scalar divide
#   return 2 * poch(s,j) * alpha**j * hyp2f1(s,s+j,j+1,alpha**2)/ factorial(j)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:353: RuntimeWarning: overflow encountered in scalar multiply
#   return 2 * poch(s,j) * alpha**j * hyp2f1(s,s+j,j+1,alpha**2)/ factorial(j)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:349: RuntimeWarning: invalid value encountered in scalar add
#   laplace_b(s+1,j-1,0,alpha)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:349: RuntimeWarning: invalid value encountered in scalar subtract
#   laplace_b(s+1,j-1,0,alpha)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:353: RuntimeWarning: overflow encountered in scalar multiply
#   return 2 * poch(s,j) * alpha**j * hyp2f1(s,s+j,j+1,alpha**2)/ factorial(j)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:349: RuntimeWarning: invalid value encountered in scalar add
#   laplace_b(s+1,j-1,0,alpha)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:349: RuntimeWarning: invalid value encountered in scalar subtract
#   laplace_b(s+1,j-1,0,alpha)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:353: RuntimeWarning: overflow encountered in scalar multiply
#   return 2 * poch(s,j) * alpha**j * hyp2f1(s,s+j,j+1,alpha**2)/ factorial(j)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:349: RuntimeWarning: invalid value encountered in scalar add
#   laplace_b(s+1,j-1,0,alpha)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:349: RuntimeWarning: invalid value encountered in scalar subtract
#   laplace_b(s+1,j-1,0,alpha)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:353: RuntimeWarning: overflow encountered in scalar multiply
#   return 2 * poch(s,j) * alpha**j * hyp2f1(s,s+j,j+1,alpha**2)/ factorial(j)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:349: RuntimeWarning: invalid value encountered in scalar add
#   laplace_b(s+1,j-1,0,alpha)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:349: RuntimeWarning: invalid value encountered in scalar subtract
#   laplace_b(s+1,j-1,0,alpha)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:353: RuntimeWarning: overflow encountered in scalar multiply
#   return 2 * poch(s,j) * alpha**j * hyp2f1(s,s+j,j+1,alpha**2)/ factorial(j)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:349: RuntimeWarning: invalid value encountered in scalar add
#   laplace_b(s+1,j-1,0,alpha)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:349: RuntimeWarning: invalid value encountered in scalar subtract
#   laplace_b(s+1,j-1,0,alpha)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:353: RuntimeWarning: overflow encountered in scalar multiply
#   return 2 * poch(s,j) * alpha**j * hyp2f1(s,s+j,j+1,alpha**2)/ factorial(j)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:349: RuntimeWarning: invalid value encountered in scalar add
#   laplace_b(s+1,j-1,0,alpha)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:349: RuntimeWarning: invalid value encountered in scalar subtract
#   laplace_b(s+1,j-1,0,alpha)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:353: RuntimeWarning: overflow encountered in scalar multiply
#   return 2 * poch(s,j) * alpha**j * hyp2f1(s,s+j,j+1,alpha**2)/ factorial(j)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:349: RuntimeWarning: invalid value encountered in scalar add
#   laplace_b(s+1,j-1,0,alpha)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:349: RuntimeWarning: invalid value encountered in scalar subtract
#   laplace_b(s+1,j-1,0,alpha)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:353: RuntimeWarning: overflow encountered in scalar multiply
#   return 2 * poch(s,j) * alpha**j * hyp2f1(s,s+j,j+1,alpha**2)/ factorial(j)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:349: RuntimeWarning: invalid value encountered in scalar add
#   laplace_b(s+1,j-1,0,alpha)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:349: RuntimeWarning: invalid value encountered in scalar subtract
#   laplace_b(s+1,j-1,0,alpha)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:353: RuntimeWarning: overflow encountered in scalar multiply
#   return 2 * poch(s,j) * alpha**j * hyp2f1(s,s+j,j+1,alpha**2)/ factorial(j)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:349: RuntimeWarning: invalid value encountered in scalar add
#   laplace_b(s+1,j-1,0,alpha)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:349: RuntimeWarning: invalid value encountered in scalar subtract
#   laplace_b(s+1,j-1,0,alpha)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:353: RuntimeWarning: overflow encountered in scalar multiply
#   return 2 * poch(s,j) * alpha**j * hyp2f1(s,s+j,j+1,alpha**2)/ factorial(j)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:349: RuntimeWarning: invalid value encountered in scalar add
#   laplace_b(s+1,j-1,0,alpha)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:353: RuntimeWarning: overflow encountered in scalar multiply
#   return 2 * poch(s,j) * alpha**j * hyp2f1(s,s+j,j+1,alpha**2)/ factorial(j)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:349: RuntimeWarning: invalid value encountered in scalar add
#   laplace_b(s+1,j-1,0,alpha)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:349: RuntimeWarning: invalid value encountered in scalar subtract
#   laplace_b(s+1,j-1,0,alpha)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:353: RuntimeWarning: invalid value encountered in scalar divide
#   return 2 * poch(s,j) * alpha**j * hyp2f1(s,s+j,j+1,alpha**2)/ factorial(j)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:353: RuntimeWarning: overflow encountered in scalar multiply
#   return 2 * poch(s,j) * alpha**j * hyp2f1(s,s+j,j+1,alpha**2)/ factorial(j)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:349: RuntimeWarning: invalid value encountered in scalar add
#   laplace_b(s+1,j-1,0,alpha)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:349: RuntimeWarning: invalid value encountered in scalar subtract
#   laplace_b(s+1,j-1,0,alpha)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:353: RuntimeWarning: overflow encountered in scalar multiply
#   return 2 * poch(s,j) * alpha**j * hyp2f1(s,s+j,j+1,alpha**2)/ factorial(j)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:349: RuntimeWarning: invalid value encountered in scalar add
#   laplace_b(s+1,j-1,0,alpha)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:349: RuntimeWarning: invalid value encountered in scalar subtract
#   laplace_b(s+1,j-1,0,alpha)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:353: RuntimeWarning: overflow encountered in scalar multiply
#   return 2 * poch(s,j) * alpha**j * hyp2f1(s,s+j,j+1,alpha**2)/ factorial(j)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:349: RuntimeWarning: invalid value encountered in scalar add
#   laplace_b(s+1,j-1,0,alpha)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:349: RuntimeWarning: invalid value encountered in scalar subtract
#   laplace_b(s+1,j-1,0,alpha)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:353: RuntimeWarning: overflow encountered in scalar multiply
#   return 2 * poch(s,j) * alpha**j * hyp2f1(s,s+j,j+1,alpha**2)/ factorial(j)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:349: RuntimeWarning: invalid value encountered in scalar add
#   laplace_b(s+1,j-1,0,alpha)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:349: RuntimeWarning: invalid value encountered in scalar subtract
#   laplace_b(s+1,j-1,0,alpha)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:353: RuntimeWarning: overflow encountered in scalar multiply
#   return 2 * poch(s,j) * alpha**j * hyp2f1(s,s+j,j+1,alpha**2)/ factorial(j)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:349: RuntimeWarning: invalid value encountered in scalar add
#   laplace_b(s+1,j-1,0,alpha)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:349: RuntimeWarning: invalid value encountered in scalar subtract
#   laplace_b(s+1,j-1,0,alpha)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:353: RuntimeWarning: overflow encountered in scalar multiply
#   return 2 * poch(s,j) * alpha**j * hyp2f1(s,s+j,j+1,alpha**2)/ factorial(j)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:349: RuntimeWarning: invalid value encountered in scalar add
#   laplace_b(s+1,j-1,0,alpha)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:349: RuntimeWarning: invalid value encountered in scalar subtract
#   laplace_b(s+1,j-1,0,alpha)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:353: RuntimeWarning: overflow encountered in scalar multiply
#   return 2 * poch(s,j) * alpha**j * hyp2f1(s,s+j,j+1,alpha**2)/ factorial(j)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:349: RuntimeWarning: invalid value encountered in scalar add
#   laplace_b(s+1,j-1,0,alpha)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:349: RuntimeWarning: invalid value encountered in scalar subtract
#   laplace_b(s+1,j-1,0,alpha)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:353: RuntimeWarning: overflow encountered in scalar multiply
#   return 2 * poch(s,j) * alpha**j * hyp2f1(s,s+j,j+1,alpha**2)/ factorial(j)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:349: RuntimeWarning: invalid value encountered in scalar add
#   laplace_b(s+1,j-1,0,alpha)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:349: RuntimeWarning: invalid value encountered in scalar subtract
#   laplace_b(s+1,j-1,0,alpha)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:353: RuntimeWarning: overflow encountered in scalar multiply
#   return 2 * poch(s,j) * alpha**j * hyp2f1(s,s+j,j+1,alpha**2)/ factorial(j)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:349: RuntimeWarning: invalid value encountered in scalar add
#   laplace_b(s+1,j-1,0,alpha)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:349: RuntimeWarning: invalid value encountered in scalar subtract
#   laplace_b(s+1,j-1,0,alpha)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:353: RuntimeWarning: invalid value encountered in scalar divide
#   return 2 * poch(s,j) * alpha**j * hyp2f1(s,s+j,j+1,alpha**2)/ factorial(j)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:353: RuntimeWarning: overflow encountered in scalar multiply
#   return 2 * poch(s,j) * alpha**j * hyp2f1(s,s+j,j+1,alpha**2)/ factorial(j)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:349: RuntimeWarning: invalid value encountered in scalar add
#   laplace_b(s+1,j-1,0,alpha)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:349: RuntimeWarning: invalid value encountered in scalar subtract
#   laplace_b(s+1,j-1,0,alpha)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:353: RuntimeWarning: overflow encountered in scalar multiply
#   return 2 * poch(s,j) * alpha**j * hyp2f1(s,s+j,j+1,alpha**2)/ factorial(j)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:349: RuntimeWarning: invalid value encountered in scalar add
#   laplace_b(s+1,j-1,0,alpha)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:349: RuntimeWarning: invalid value encountered in scalar subtract
#   laplace_b(s+1,j-1,0,alpha)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:353: RuntimeWarning: overflow encountered in scalar multiply
#   return 2 * poch(s,j) * alpha**j * hyp2f1(s,s+j,j+1,alpha**2)/ factorial(j)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:349: RuntimeWarning: invalid value encountered in scalar add
#   laplace_b(s+1,j-1,0,alpha)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:349: RuntimeWarning: invalid value encountered in scalar subtract
#   laplace_b(s+1,j-1,0,alpha)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:353: RuntimeWarning: overflow encountered in scalar multiply
#   return 2 * poch(s,j) * alpha**j * hyp2f1(s,s+j,j+1,alpha**2)/ factorial(j)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:349: RuntimeWarning: invalid value encountered in scalar add
#   laplace_b(s+1,j-1,0,alpha)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:349: RuntimeWarning: invalid value encountered in scalar subtract
#   laplace_b(s+1,j-1,0,alpha)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:353: RuntimeWarning: overflow encountered in scalar multiply
#   return 2 * poch(s,j) * alpha**j * hyp2f1(s,s+j,j+1,alpha**2)/ factorial(j)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:349: RuntimeWarning: invalid value encountered in scalar add
#   laplace_b(s+1,j-1,0,alpha)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:349: RuntimeWarning: invalid value encountered in scalar subtract
#   laplace_b(s+1,j-1,0,alpha)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:353: RuntimeWarning: overflow encountered in scalar multiply
#   return 2 * poch(s,j) * alpha**j * hyp2f1(s,s+j,j+1,alpha**2)/ factorial(j)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:349: RuntimeWarning: invalid value encountered in scalar add
#   laplace_b(s+1,j-1,0,alpha)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:349: RuntimeWarning: invalid value encountered in scalar subtract
#   laplace_b(s+1,j-1,0,alpha)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:353: RuntimeWarning: invalid value encountered in scalar divide
#   return 2 * poch(s,j) * alpha**j * hyp2f1(s,s+j,j+1,alpha**2)/ factorial(j)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:353: RuntimeWarning: overflow encountered in scalar multiply
#   return 2 * poch(s,j) * alpha**j * hyp2f1(s,s+j,j+1,alpha**2)/ factorial(j)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:349: RuntimeWarning: invalid value encountered in scalar add
#   laplace_b(s+1,j-1,0,alpha)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:349: RuntimeWarning: invalid value encountered in scalar subtract
#   laplace_b(s+1,j-1,0,alpha)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:353: RuntimeWarning: overflow encountered in scalar multiply
#   return 2 * poch(s,j) * alpha**j * hyp2f1(s,s+j,j+1,alpha**2)/ factorial(j)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:349: RuntimeWarning: invalid value encountered in scalar add
#   laplace_b(s+1,j-1,0,alpha)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:349: RuntimeWarning: invalid value encountered in scalar subtract
#   laplace_b(s+1,j-1,0,alpha)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:353: RuntimeWarning: overflow encountered in scalar multiply
#   return 2 * poch(s,j) * alpha**j * hyp2f1(s,s+j,j+1,alpha**2)/ factorial(j)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:349: RuntimeWarning: invalid value encountered in scalar add
#   laplace_b(s+1,j-1,0,alpha)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:349: RuntimeWarning: invalid value encountered in scalar subtract
#   laplace_b(s+1,j-1,0,alpha)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:353: RuntimeWarning: invalid value encountered in scalar divide
#   return 2 * poch(s,j) * alpha**j * hyp2f1(s,s+j,j+1,alpha**2)/ factorial(j)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:353: RuntimeWarning: invalid value encountered in scalar divide
#   return 2 * poch(s,j) * alpha**j * hyp2f1(s,s+j,j+1,alpha**2)/ factorial(j)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:353: RuntimeWarning: overflow encountered in scalar multiply
#   return 2 * poch(s,j) * alpha**j * hyp2f1(s,s+j,j+1,alpha**2)/ factorial(j)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:349: RuntimeWarning: invalid value encountered in scalar add
#   laplace_b(s+1,j-1,0,alpha)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:349: RuntimeWarning: invalid value encountered in scalar subtract
#   laplace_b(s+1,j-1,0,alpha)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:353: RuntimeWarning: overflow encountered in scalar multiply
#   return 2 * poch(s,j) * alpha**j * hyp2f1(s,s+j,j+1,alpha**2)/ factorial(j)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:349: RuntimeWarning: invalid value encountered in scalar add
#   laplace_b(s+1,j-1,0,alpha)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:349: RuntimeWarning: invalid value encountered in scalar subtract
#   laplace_b(s+1,j-1,0,alpha)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:353: RuntimeWarning: invalid value encountered in scalar divide
#   return 2 * poch(s,j) * alpha**j * hyp2f1(s,s+j,j+1,alpha**2)/ factorial(j)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:353: RuntimeWarning: overflow encountered in scalar multiply
#   return 2 * poch(s,j) * alpha**j * hyp2f1(s,s+j,j+1,alpha**2)/ factorial(j)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:349: RuntimeWarning: invalid value encountered in scalar add
#   laplace_b(s+1,j-1,0,alpha)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:349: RuntimeWarning: invalid value encountered in scalar subtract
#   laplace_b(s+1,j-1,0,alpha)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:353: RuntimeWarning: invalid value encountered in scalar divide
#   return 2 * poch(s,j) * alpha**j * hyp2f1(s,s+j,j+1,alpha**2)/ factorial(j)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:353: RuntimeWarning: overflow encountered in scalar multiply
#   return 2 * poch(s,j) * alpha**j * hyp2f1(s,s+j,j+1,alpha**2)/ factorial(j)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:349: RuntimeWarning: invalid value encountered in scalar add
#   laplace_b(s+1,j-1,0,alpha)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:349: RuntimeWarning: invalid value encountered in scalar subtract
#   laplace_b(s+1,j-1,0,alpha)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:353: RuntimeWarning: invalid value encountered in scalar divide
#   return 2 * poch(s,j) * alpha**j * hyp2f1(s,s+j,j+1,alpha**2)/ factorial(j)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:353: RuntimeWarning: overflow encountered in scalar multiply
#   return 2 * poch(s,j) * alpha**j * hyp2f1(s,s+j,j+1,alpha**2)/ factorial(j)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:349: RuntimeWarning: invalid value encountered in scalar add
#   laplace_b(s+1,j-1,0,alpha)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:349: RuntimeWarning: invalid value encountered in scalar subtract
#   laplace_b(s+1,j-1,0,alpha)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:353: RuntimeWarning: invalid value encountered in scalar divide
#   return 2 * poch(s,j) * alpha**j * hyp2f1(s,s+j,j+1,alpha**2)/ factorial(j)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:353: RuntimeWarning: overflow encountered in scalar multiply
#   return 2 * poch(s,j) * alpha**j * hyp2f1(s,s+j,j+1,alpha**2)/ factorial(j)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:349: RuntimeWarning: invalid value encountered in scalar add
#   laplace_b(s+1,j-1,0,alpha)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:349: RuntimeWarning: invalid value encountered in scalar subtract
#   laplace_b(s+1,j-1,0,alpha)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:353: RuntimeWarning: overflow encountered in scalar multiply
#   return 2 * poch(s,j) * alpha**j * hyp2f1(s,s+j,j+1,alpha**2)/ factorial(j)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:349: RuntimeWarning: invalid value encountered in scalar add
#   laplace_b(s+1,j-1,0,alpha)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:349: RuntimeWarning: invalid value encountered in scalar subtract
#   laplace_b(s+1,j-1,0,alpha)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:353: RuntimeWarning: overflow encountered in scalar multiply
#   return 2 * poch(s,j) * alpha**j * hyp2f1(s,s+j,j+1,alpha**2)/ factorial(j)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:349: RuntimeWarning: invalid value encountered in scalar add
#   laplace_b(s+1,j-1,0,alpha)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:349: RuntimeWarning: invalid value encountered in scalar subtract
#   laplace_b(s+1,j-1,0,alpha)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:353: RuntimeWarning: invalid value encountered in scalar divide
#   return 2 * poch(s,j) * alpha**j * hyp2f1(s,s+j,j+1,alpha**2)/ factorial(j)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:353: RuntimeWarning: overflow encountered in scalar multiply
#   return 2 * poch(s,j) * alpha**j * hyp2f1(s,s+j,j+1,alpha**2)/ factorial(j)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:349: RuntimeWarning: invalid value encountered in scalar add
#   laplace_b(s+1,j-1,0,alpha)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:349: RuntimeWarning: invalid value encountered in scalar subtract
#   laplace_b(s+1,j-1,0,alpha)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:353: RuntimeWarning: overflow encountered in scalar multiply
#   return 2 * poch(s,j) * alpha**j * hyp2f1(s,s+j,j+1,alpha**2)/ factorial(j)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:349: RuntimeWarning: invalid value encountered in scalar add
#   laplace_b(s+1,j-1,0,alpha)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:349: RuntimeWarning: invalid value encountered in scalar subtract
#   laplace_b(s+1,j-1,0,alpha)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:353: RuntimeWarning: overflow encountered in scalar multiply
#   return 2 * poch(s,j) * alpha**j * hyp2f1(s,s+j,j+1,alpha**2)/ factorial(j)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:349: RuntimeWarning: invalid value encountered in scalar add
#   laplace_b(s+1,j-1,0,alpha)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:349: RuntimeWarning: invalid value encountered in scalar subtract
#   laplace_b(s+1,j-1,0,alpha)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:353: RuntimeWarning: overflow encountered in scalar multiply
#   return 2 * poch(s,j) * alpha**j * hyp2f1(s,s+j,j+1,alpha**2)/ factorial(j)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:349: RuntimeWarning: invalid value encountered in scalar add
#   laplace_b(s+1,j-1,0,alpha)
# /home/miniconda3/envs/sorobertson/lib/python3.12/site-packages/celmech/disturbing_function.py:349: RuntimeWarning: invalid value encountered in scalar subtract
#   laplace_b(s+1,j-1,0,alpha)

# %% [markdown]
# We can then join the generated features with the corresponding labels

# %%
dataset = pd.DataFrame.join(formattedFeat,labels)

# %% [markdown]
# We can then save the new training data spreadsheet.

# %%
dataset.to_csv(datapath+'massFacs.csv')
